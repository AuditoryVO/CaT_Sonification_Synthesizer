# %% [markdown]
# # Unsupervised exploration of the CaT stellar library
#
# Data download: http://svocats.cab.inta-csic.es/catlib
#
# #### ACKNOWLEDGMENT
# This work is based on data from the CaT service developed by the Spanish Virtual Observatory in the framework of the IAU Comission G5 Working Group : Spectral Stellar Libraries.

# %%
from astropy.io import fits
import matplotlib.pylab as plt
import numpy as np

from pythonosc import udp_client
import time

import os
from fnmatch import fnmatch

from pathlib import Path

# %%
root = '## YOUR FOLDER PATH TO THE DOWNLOADED SPECTRA ##'
target = "scan001.fits"

# %%
for path, subdirs, files in os.walk(root):
    for name in files:
        if fnmatch(name, target):
            print([os.path.join(path, name)])
# Out:
# ['/Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan001.fits']

# %%
file = [os.path.join(path, name)]
str = " " 
Ffile = (str.join(file))  
route = Path(Ffile)
Fname = route.with_suffix('')

# %%
type (Ffile)
print (Ffile)
print (Fname)
# Out:
# /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan347.fits
# /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan347

# %%
file[0]
# Out:
# '/Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan347.fits'

# %%
files
# Out:
# ['scan446.fits',
#  'scan016.fits',
#  'scan503.fits',
#  'scan153.fits',
#  'scan295.fits',
#  'scan041.fits',
#  'scan411.fits',
#  'scan104.fits',
#  'scan554.fits',
#  'scan387.fits',
#  'scan692.fits',
#  'scan368.fits',
#  'scan407.fits',
#  'scan057.fits',
#  'scan542.fits',
#  'scan112.fits',
#  'scan391.fits',
#  'scan684.fits',
#  'scan450.fits',
#  'scan145.fits',
#  'scan515.fits',
#  'scan283.fits',
#  'scan329.fits',
#  'scan094.fits',
#  'scan581.fits',
#  'scan702.fits',
#  'scan352.fits',
#  'scan647.fits',
#  'scan217.fits',
#  'scan539.fits',
#  'scan493.fits',
#  'scan169.fits',
#  'scan186.fits',
#  'scan305.fits',
#  'scan240.fits',
#  'scan610.fits',
#  'scan485.fits',
#  'scan190.fits',
#  'scan313.fits',
#  'scan606.fits',
#  'scan256.fits',
#  'scan082.fits',
#  'scan578.fits',
#  'scan128.fits',
#  'scan597.fits',
#  'scan344.fits',
#  'scan201.fits',
#  'scan651.fits',
#  'scan626.fits',
#  'scan276.fits',
#  'scan299.fits',
#  'scan333.fits',
#  'scan221.fits',
#  'scan671.fits',
#  'scan364.fits',
#  'scan558.fits',
#  'scan108.fits',
#  'scan667.fits',
#  'scan237.fits',
#  'scan688.fits',
#  'scan372.fits',
#  'scan260.fits',
#  'scan630.fits',
#  'scan325.fits',
#  'scan519.fits',
#  'scan149.fits',
#  'scan098.fits',
#  'scan562.fits',
#  'scan132.fits',
#  'scan427.fits',
#  'scan077.fits',
#  'scan309.fits',
#  'scan165.fits',
#  'scan535.fits',
#  'scan020.fits',
#  'scan470.fits',
#  'scan523.fits',
#  'scan489.fits',
#  'scan173.fits',
#  'scan466.fits',
#  'scan036.fits',
#  'scan348.fits',
#  'scan124.fits',
#  'scan574.fits',
#  'scan061.fits',
#  'scan431.fits',
#  'scan125.fits',
#  'scan575.fits',
#  'scan060.fits',
#  'scan430.fits',
#  'scan349.fits',
#  'scan522.fits',
#  'scan488.fits',
#  'scan172.fits',
#  'scan467.fits',
#  'scan037.fits',
#  'scan164.fits',
#  'scan534.fits',
#  'scan021.fits',
#  'scan471.fits',
#  'scan308.fits',
#  'scan099.fits',
#  'scan563.fits',
#  'scan133.fits',
#  'scan426.fits',
#  'scan076.fits',
#  'scan518.fits',
#  'scan148.fits',
#  'scan261.fits',
#  'scan631.fits',
#  'scan324.fits',
#  'scan666.fits',
#  'scan236.fits',
#  'scan689.fits',
#  'scan373.fits',
#  'scan559.fits',
#  'scan109.fits',
#  'scan220.fits',
#  'scan670.fits',
#  'scan365.fits',
#  'scan627.fits',
#  'scan277.fits',
#  'scan298.fits',
#  'scan332.fits',
#  'scan345.fits',
#  'scan200.fits',
#  'scan650.fits',
#  'scan083.fits',
#  'scan579.fits',
#  'scan129.fits',
#  'scan596.fits',
#  'scan312.fits',
#  'scan607.fits',
#  'scan257.fits',
#  'scan484.fits',
#  'scan191.fits',
#  'scan304.fits',
#  'scan241.fits',
#  'scan611.fits',
#  'scan538.fits',
#  'scan492.fits',
#  'scan168.fits',
#  'scan187.fits',
#  'scan703.fits',
#  'scan353.fits',
#  'scan646.fits',
#  'scan216.fits',
#  'scan095.fits',
#  'scan580.fits',
#  'scan282.fits',
#  'scan328.fits',
#  'scan001.fits',
#  'scan451.fits',
#  'scan144.fits',
#  'scan514.fits',
#  'scan390.fits',
#  'scan685.fits',
#  'scan406.fits',
#  'scan056.fits',
#  'scan543.fits',
#  'scan113.fits',
#  'scan386.fits',
#  'scan693.fits',
#  'scan369.fits',
#  'scan040.fits',
#  'scan410.fits',
#  'scan105.fits',
#  'scan555.fits',
#  'scan294.fits',
#  'scan447.fits',
#  'scan017.fits',
#  'scan502.fits',
#  'scan152.fits',
#  'scan620.fits',
#  'scan270.fits',
#  'scan335.fits',
#  'scan159.fits',
#  'scan509.fits',
#  'scan227.fits',
#  'scan677.fits',
#  'scan698.fits',
#  'scan362.fits',
#  'scan661.fits',
#  'scan231.fits',
#  'scan374.fits',
#  'scan118.fits',
#  'scan548.fits',
#  'scan266.fits',
#  'scan636.fits',
#  'scan323.fits',
#  'scan289.fits',
#  'scan358.fits',
#  'scan564.fits',
#  'scan134.fits',
#  'scan421.fits',
#  'scan071.fits',
#  'scan499.fits',
#  'scan163.fits',
#  'scan533.fits',
#  'scan026.fits',
#  'scan476.fits',
#  'scan319.fits',
#  'scan525.fits',
#  'scan175.fits',
#  'scan460.fits',
#  'scan030.fits',
#  'scan122.fits',
#  'scan088.fits',
#  'scan572.fits',
#  'scan067.fits',
#  'scan437.fits',
#  'scan440.fits',
#  'scan010.fits',
#  'scan505.fits',
#  'scan155.fits',
#  'scan339.fits',
#  'scan293.fits',
#  'scan047.fits',
#  'scan417.fits',
#  'scan102.fits',
#  'scan552.fits',
#  'scan381.fits',
#  'scan694.fits',
#  'scan401.fits',
#  'scan051.fits',
#  'scan544.fits',
#  'scan114.fits',
#  'scan397.fits',
#  'scan682.fits',
#  'scan378.fits',
#  'scan006.fits',
#  'scan456.fits',
#  'scan143.fits',
#  'scan513.fits',
#  'scan285.fits',
#  'scan138.fits',
#  'scan092.fits',
#  'scan568.fits',
#  'scan587.fits',
#  'scan704.fits',
#  'scan354.fits',
#  'scan641.fits',
#  'scan211.fits',
#  'scan495.fits',
#  'scan180.fits',
#  'scan303.fits',
#  'scan246.fits',
#  'scan616.fits',
#  'scan483.fits',
#  'scan179.fits',
#  'scan529.fits',
#  'scan196.fits',
#  'scan315.fits',
#  'scan600.fits',
#  'scan250.fits',
#  'scan084.fits',
#  'scan591.fits',
#  'scan342.fits',
#  'scan207.fits',
#  'scan657.fits',
#  'scan343.fits',
#  'scan206.fits',
#  'scan656.fits',
#  'scan085.fits',
#  'scan590.fits',
#  'scan314.fits',
#  'scan601.fits',
#  'scan251.fits',
#  'scan482.fits',
#  'scan178.fits',
#  'scan528.fits',
#  'scan197.fits',
#  'scan302.fits',
#  'scan247.fits',
#  'scan617.fits',
#  'scan494.fits',
#  'scan181.fits',
#  'scan705.fits',
#  'scan355.fits',
#  'scan640.fits',
#  'scan210.fits',
#  'scan139.fits',
#  'scan093.fits',
#  'scan569.fits',
#  'scan586.fits',
#  'scan284.fits',
#  'scan007.fits',
#  'scan457.fits',
#  'scan142.fits',
#  'scan512.fits',
#  'scan396.fits',
#  'scan683.fits',
#  'scan379.fits',
#  'scan400.fits',
#  'scan050.fits',
#  'scan545.fits',
#  'scan115.fits',
#  'scan380.fits',
#  'scan695.fits',
#  'scan046.fits',
#  'scan416.fits',
#  'scan103.fits',
#  'scan553.fits',
#  'scan338.fits',
#  'scan292.fits',
#  'scan441.fits',
#  'scan011.fits',
#  'scan504.fits',
#  'scan154.fits',
#  'scan123.fits',
#  'scan089.fits',
#  'scan573.fits',
#  'scan066.fits',
#  'scan436.fits',
#  'scan524.fits',
#  'scan174.fits',
#  'scan461.fits',
#  'scan031.fits',
#  'scan318.fits',
#  'scan498.fits',
#  'scan162.fits',
#  'scan532.fits',
#  'scan027.fits',
#  'scan477.fits',
#  'scan565.fits',
#  'scan135.fits',
#  'scan420.fits',
#  'scan070.fits',
#  'scan359.fits',
#  'scan267.fits',
#  'scan637.fits',
#  'scan322.fits',
#  'scan288.fits',
#  'scan119.fits',
#  'scan549.fits',
#  'scan660.fits',
#  'scan230.fits',
#  'scan375.fits',
#  'scan226.fits',
#  'scan676.fits',
#  'scan699.fits',
#  'scan363.fits',
#  'scan158.fits',
#  'scan508.fits',
#  'scan621.fits',
#  'scan271.fits',
#  'scan334.fits',
#  'scan065.fits',
#  'scan435.fits',
#  'scan120.fits',
#  'scan570.fits',
#  'scan659.fits',
#  'scan209.fits',
#  'scan198.fits',
#  'scan462.fits',
#  'scan032.fits',
#  'scan527.fits',
#  'scan177.fits',
#  'scan024.fits',
#  'scan474.fits',
#  'scan161.fits',
#  'scan531.fits',
#  'scan618.fits',
#  'scan248.fits',
#  'scan423.fits',
#  'scan589.fits',
#  'scan073.fits',
#  'scan566.fits',
#  'scan136.fits',
#  'scan458.fits',
#  'scan008.fits',
#  'scan321.fits',
#  'scan264.fits',
#  'scan634.fits',
#  'scan376.fits',
#  'scan399.fits',
#  'scan663.fits',
#  'scan233.fits',
#  'scan419.fits',
#  'scan049.fits',
#  'scan360.fits',
#  'scan225.fits',
#  'scan675.fits',
#  'scan337.fits',
#  'scan622.fits',
#  'scan272.fits',
#  'scan205.fits',
#  'scan655.fits',
#  'scan340.fits',
#  'scan439.fits',
#  'scan593.fits',
#  'scan069.fits',
#  'scan086.fits',
#  'scan602.fits',
#  'scan252.fits',
#  'scan317.fits',
#  'scan194.fits',
#  'scan481.fits',
#  'scan244.fits',
#  'scan614.fits',
#  'scan301.fits',
#  'scan182.fits',
#  'scan478.fits',
#  'scan028.fits',
#  'scan497.fits',
#  'scan643.fits',
#  'scan213.fits',
#  'scan706.fits',
#  'scan356.fits',
#  'scan585.fits',
#  'scan090.fits',
#  'scan287.fits',
#  'scan638.fits',
#  'scan268.fits',
#  'scan141.fits',
#  'scan511.fits',
#  'scan004.fits',
#  'scan454.fits',
#  'scan680.fits',
#  'scan395.fits',
#  'scan546.fits',
#  'scan116.fits',
#  'scan403.fits',
#  'scan053.fits',
#  'scan696.fits',
#  'scan383.fits',
#  'scan679.fits',
#  'scan229.fits',
#  'scan100.fits',
#  'scan550.fits',
#  'scan045.fits',
#  'scan415.fits',
#  'scan291.fits',
#  'scan507.fits',
#  'scan157.fits',
#  'scan442.fits',
#  'scan012.fits',
#  'scan506.fits',
#  'scan156.fits',
#  'scan443.fits',
#  'scan013.fits',
#  'scan290.fits',
#  'scan101.fits',
#  'scan551.fits',
#  'scan044.fits',
#  'scan414.fits',
#  'scan697.fits',
#  'scan382.fits',
#  'scan678.fits',
#  'scan228.fits',
#  'scan547.fits',
#  'scan117.fits',
#  'scan402.fits',
#  'scan052.fits',
#  'scan681.fits',
#  'scan394.fits',
#  'scan140.fits',
#  'scan510.fits',
#  'scan005.fits',
#  'scan455.fits',
#  'scan286.fits',
#  'scan639.fits',
#  'scan269.fits',
#  'scan584.fits',
#  'scan091.fits',
#  'scan642.fits',
#  'scan212.fits',
#  'scan357.fits',
#  'scan183.fits',
#  'scan479.fits',
#  'scan029.fits',
#  'scan496.fits',
#  'scan245.fits',
#  'scan615.fits',
#  'scan300.fits',
#  'scan195.fits',
#  'scan480.fits',
#  'scan603.fits',
#  'scan253.fits',
#  'scan316.fits',
#  'scan438.fits',
#  'scan592.fits',
#  'scan068.fits',
#  'scan087.fits',
#  'scan204.fits',
#  'scan654.fits',
#  'scan341.fits',
#  'scan336.fits',
#  'scan623.fits',
#  'scan273.fits',
#  'scan361.fits',
#  'scan224.fits',
#  'scan674.fits',
#  'scan418.fits',
#  'scan048.fits',
#  'scan377.fits',
#  'scan398.fits',
#  'scan662.fits',
#  'scan232.fits',
#  'scan320.fits',
#  'scan265.fits',
#  'scan635.fits',
#  'scan459.fits',
#  'scan009.fits',
#  'scan422.fits',
#  'scan588.fits',
#  'scan072.fits',
#  'scan567.fits',
#  'scan137.fits',
#  'scan619.fits',
#  'scan249.fits',
#  'scan025.fits',
#  'scan475.fits',
#  'scan160.fits',
#  'scan530.fits',
#  'scan199.fits',
#  'scan463.fits',
#  'scan033.fits',
#  'scan526.fits',
#  'scan176.fits',
#  'scan658.fits',
#  'scan208.fits',
#  'scan064.fits',
#  'scan434.fits',
#  'scan121.fits',
#  'scan571.fits',
#  'scan203.fits',
#  'scan653.fits',
#  'scan346.fits',
#  'scan595.fits',
#  'scan080.fits',
#  'scan604.fits',
#  'scan254.fits',
#  'scan311.fits',
#  'scan038.fits',
#  'scan192.fits',
#  'scan468.fits',
#  'scan487.fits',
#  'scan242.fits',
#  'scan612.fits',
#  'scan307.fits',
#  'scan184.fits',
#  'scan491.fits',
#  'scan645.fits',
#  'scan215.fits',
#  'scan700.fits',
#  'scan350.fits',
#  'scan583.fits',
#  'scan079.fits',
#  'scan429.fits',
#  'scan096.fits',
#  'scan281.fits',
#  'scan147.fits',
#  'scan517.fits',
#  'scan002.fits',
#  'scan452.fits',
#  'scan686.fits',
#  'scan239.fits',
#  'scan393.fits',
#  'scan669.fits',
#  'scan540.fits',
#  'scan110.fits',
#  'scan405.fits',
#  'scan055.fits',
#  'scan690.fits',
#  'scan385.fits',
#  'scan106.fits',
#  'scan556.fits',
#  'scan043.fits',
#  'scan413.fits',
#  'scan297.fits',
#  'scan278.fits',
#  'scan628.fits',
#  'scan501.fits',
#  'scan151.fits',
#  'scan444.fits',
#  'scan014.fits',
#  'scan599.fits',
#  'scan063.fits',
#  'scan433.fits',
#  'scan126.fits',
#  'scan576.fits',
#  'scan464.fits',
#  'scan034.fits',
#  'scan521.fits',
#  'scan171.fits',
#  'scan258.fits',
#  'scan608.fits',
#  'scan022.fits',
#  'scan188.fits',
#  'scan472.fits',
#  'scan167.fits',
#  'scan537.fits',
#  'scan425.fits',
#  'scan075.fits',
#  'scan560.fits',
#  'scan130.fits',
#  'scan219.fits',
#  'scan649.fits',
#  'scan327.fits',
#  'scan262.fits',
#  'scan632.fits',
#  'scan059.fits',
#  'scan409.fits',
#  'scan370.fits',
#  'scan665.fits',
#  'scan235.fits',
#  'scan366.fits',
#  'scan223.fits',
#  'scan389.fits',
#  'scan673.fits',
#  'scan018.fits',
#  'scan448.fits',
#  'scan331.fits',
#  'scan624.fits',
#  'scan274.fits',
#  'scan330.fits',
#  'scan625.fits',
#  'scan275.fits',
#  'scan019.fits',
#  'scan449.fits',
#  'scan367.fits',
#  'scan222.fits',
#  'scan388.fits',
#  'scan672.fits',
#  'scan371.fits',
#  'scan664.fits',
#  'scan234.fits',
#  'scan058.fits',
#  'scan408.fits',
#  'scan326.fits',
#  'scan263.fits',
#  'scan633.fits',
#  'scan218.fits',
#  'scan648.fits',
#  'scan424.fits',
#  'scan074.fits',
#  'scan561.fits',
#  'scan131.fits',
#  'scan023.fits',
#  'scan189.fits',
#  'scan473.fits',
#  'scan166.fits',
#  'scan536.fits',
#  'scan259.fits',
#  'scan609.fits',
#  'scan465.fits',
#  'scan035.fits',
#  'scan520.fits',
#  'scan170.fits',
#  'scan598.fits',
#  'scan062.fits',
#  'scan432.fits',
#  'scan127.fits',
#  'scan577.fits',
#  'scan500.fits',
#  'scan150.fits',
#  'scan445.fits',
#  'scan015.fits',
#  'scan296.fits',
#  'scan279.fits',
#  'scan629.fits',
#  'scan107.fits',
#  'scan557.fits',
#  'scan042.fits',
#  'scan412.fits',
#  'scan691.fits',
#  'scan384.fits',
#  'scan541.fits',
#  'scan111.fits',
#  'scan404.fits',
#  'scan054.fits',
#  'scan687.fits',
#  'scan238.fits',
#  'scan392.fits',
#  'scan668.fits',
#  'scan146.fits',
#  'scan516.fits',
#  'scan003.fits',
#  'scan453.fits',
#  'scan280.fits',
#  'scan582.fits',
#  'scan078.fits',
#  'scan428.fits',
#  'scan097.fits',
#  'scan644.fits',
#  'scan214.fits',
#  'scan701.fits',
#  'scan351.fits',
#  'scan185.fits',
#  'scan490.fits',
#  'scan243.fits',
#  'scan613.fits',
#  'scan306.fits',
#  'scan039.fits',
#  'scan193.fits',
#  'scan469.fits',
#  'scan486.fits',
#  'scan605.fits',
#  'scan255.fits',
#  'scan310.fits',
#  'scan594.fits',
#  'scan081.fits',
#  'scan202.fits',
#  'scan652.fits',
#  'scan347.fits']

# %%
file
# Out:
# ['/Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan347.fits']

# %%
from astropy.io import fits

file = "/Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan145.fits"#input('Path and name of the fits-file: ')

sp = fits.open(file)
print('\n\nHeader of the spectrum :\n\n', sp[0].header, '\n\n')

flux2 = np.zeros(sp[0].header['NAXIS1'], dtype=float)

flux2 = np.array(sp[0].data)
flux_norm = flux2/(np.nanmax(flux2))

wave2 = np.ones(sp[0].header['NAXIS1'], dtype=float)
for i in range(sp[0].header['NAXIS1']):
    wave2[i] = sp[0].header['CRVAL1'] + i*sp[0].header['CDELT1']
# Out:
# Header of the spectrum :
#
#  SIMPLE  =                    T / file does conform to FITS standard             BITPIX  =                  -32 / number of bits per data pixel                  NAXIS   =                    2 / number of data axes                            NAXIS1  =                  790 / length of data axis 1                          NAXIS2  =                    1 / length of data axis 2                          COMMENT   FITS (Flexible Image Transport System) format defined in Astronomy andCOMMENT   Astrophysics Supplement Series v44/p363, v44/p371, v73/p359, v73/p365.COMMENT   Contact the NASA Science Office of Standards and Technology for the   COMMENT   FITS Definition document #100 and other FITS information.             COMMENT   ----------------------------------------------------------------------COMMENT   ************************** REDUCEME HEADER ***************************COMMENT   ----------------------------------------------------------------------HISTORY   Date: 07/09/01                                                        CRVAL1  =              8348.85 / central wavelength of first pixel              CDELT1  =               0.8500 / linear dispersion (Angstrom/pixel)             OBJECT  = 'NGC7789_338'        / Object name                                    FITSFI  = '[none]  '           / Object name                                    COMMENT   [from genimage]                                                       AIRMASS =              0.00000 / Airmass                                        TIMEXPO =                  0.0 / Timexpos                                       END

# %%
flux_ok = np.reshape(flux_norm, (sp[0].header['NAXIS1']))

# %%
fig = plt.figure(1, figsize=(12, 8))
plt.plot(wave2, flux_ok)
plt.xlabel('Wavelength [Å]')
plt.ylabel('ADU')
plt.title(file)
plt.show()

# %% [markdown]
# Number of files in the folder

# %%
num = 1
dim1 = sp[0].header['NAXIS1']
for path, subdirs, files in os.walk(root):
    for nanme in files:
        num += 1
print(num)
print(dim1)
# Out:
# 707
# 790

# %%
curves = 0
custom_set = np.zeros((num, dim1))
label_set = np.zeros((num, ), dtype=int)
spectra_set = [''] * num 

for path, subdirs, files in os.walk(root):
    for name in files:
        file = [os.path.join(path, name)]
        str = " " 
        Ffile = (str.join(file))
        route = Path(name)
        Fname = route.with_suffix('')
        Fpng = route.with_suffix('.png')

        data, header = fits.getdata(Ffile, header=True)
        hdu_number = 0
        fits.getheader(Ffile, hdu_number)
        fits_file = Ffile
        
        with fits.open(fits_file, mode='readonly') as hdulist:
            hdulist.info()
            data = np.array(hdulist[0].data)
             
            data_norm = np.reshape(data/(np.nanmax(data)), (sp[0].header['NAXIS1']))

            
            label_set[curves] = curves 
            spectra_set[curves] = name
            for i in range (dim1):
                custom_set[curves,i] = (data_norm[i])
        hdulist.close   
        curves += 1
   
            
#--------------------------------------------------------------------
        print ("Spectra loaded:",curves+1, "spectra");
# Out:
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan446.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 2 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan016.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 3 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan503.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 4 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan153.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 5 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan295.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 6 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan041.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 7 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan411.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 8 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan104.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 9 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan554.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 10 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan387.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 11 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan692.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 12 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan368.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 13 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan407.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 14 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan057.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 15 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan542.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 16 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan112.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 17 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan391.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 18 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan684.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 19 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan450.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 20 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan145.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 21 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan515.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 22 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan283.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 23 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan329.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 24 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan094.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 25 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan581.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 26 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan702.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 27 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan352.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 28 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan647.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 29 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan217.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 30 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan539.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 31 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan493.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 32 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan169.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 33 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan186.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 34 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan305.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 35 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan240.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 36 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan610.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 37 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan485.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 38 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan190.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 39 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan313.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 40 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan606.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 41 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan256.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 42 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan082.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 43 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan578.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 44 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan128.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 45 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan597.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 46 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan344.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 47 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan201.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 48 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan651.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 49 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan626.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 50 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan276.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 51 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan299.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 52 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan333.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 53 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan221.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 54 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan671.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 55 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan364.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 56 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan558.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 57 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan108.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 58 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan667.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 59 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan237.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 60 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan688.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 61 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan372.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 62 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan260.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 63 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan630.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 64 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan325.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 65 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan519.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 66 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan149.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 67 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan098.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 68 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan562.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 69 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan132.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 70 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan427.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 71 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan077.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 72 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan309.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 73 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan165.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 74 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan535.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 75 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan020.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 76 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan470.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 77 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan523.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 78 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan489.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 79 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan173.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 80 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan466.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 81 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan036.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 82 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan348.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 83 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan124.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 84 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan574.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 85 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan061.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 86 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan431.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 87 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan125.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 88 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan575.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 89 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan060.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 90 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan430.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 91 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan349.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 92 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan522.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 93 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan488.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 94 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan172.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 95 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan467.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 96 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan037.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 97 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan164.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 98 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan534.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 99 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan021.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 100 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan471.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 101 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan308.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 102 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan099.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 103 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan563.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 104 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan133.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 105 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan426.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 106 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan076.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 107 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan518.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 108 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan148.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 109 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan261.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 110 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan631.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 111 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan324.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 112 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan666.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 113 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan236.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 114 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan689.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 115 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan373.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 116 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan559.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 117 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan109.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 118 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan220.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 119 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan670.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 120 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan365.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 121 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan627.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 122 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan277.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 123 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan298.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 124 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan332.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 125 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan345.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 126 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan200.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 127 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan650.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 128 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan083.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 129 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan579.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 130 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan129.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 131 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan596.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 132 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan312.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 133 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan607.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 134 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan257.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 135 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan484.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 136 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan191.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 137 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan304.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 138 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan241.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 139 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan611.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 140 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan538.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 141 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan492.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 142 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan168.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 143 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan187.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 144 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan703.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 145 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan353.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 146 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan646.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 147 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan216.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 148 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan095.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 149 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan580.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 150 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan282.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 151 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan328.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 152 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan001.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 153 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan451.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 154 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan144.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 155 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan514.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 156 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan390.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 157 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan685.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 158 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan406.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 159 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan056.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 160 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan543.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 161 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan113.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 162 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan386.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 163 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan693.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 164 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan369.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 165 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan040.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 166 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan410.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 167 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan105.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 168 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan555.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 169 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan294.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 170 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan447.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 171 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan017.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 172 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan502.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 173 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan152.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 174 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan620.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 175 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan270.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 176 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan335.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 177 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan159.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 178 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan509.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 179 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan227.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 180 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan677.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 181 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan698.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 182 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan362.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 183 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan661.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 184 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan231.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 185 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan374.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 186 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan118.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 187 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan548.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 188 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan266.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 189 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan636.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 190 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan323.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 191 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan289.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 192 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan358.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 193 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan564.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 194 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan134.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 195 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan421.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 196 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan071.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 197 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan499.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 198 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan163.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 199 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan533.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 200 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan026.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 201 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan476.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 202 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan319.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 203 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan525.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 204 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan175.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
# ...
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 640 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan023.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 641 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan189.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 642 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan473.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 643 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan166.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 644 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan536.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 645 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan259.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 646 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan609.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 647 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan465.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 648 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan035.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 649 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan520.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 650 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan170.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 651 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan598.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 652 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan062.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 653 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan432.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 654 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan127.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 655 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan577.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 656 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan500.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 657 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan150.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 658 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan445.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 659 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan015.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 660 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan296.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 661 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan279.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 662 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan629.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 663 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan107.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 664 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan557.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 665 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan042.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 666 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan412.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 667 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan691.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 668 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan384.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 669 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan541.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 670 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan111.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 671 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan404.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 672 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan054.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 673 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan687.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 674 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan238.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 675 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan392.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 676 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan668.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 677 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan146.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 678 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan516.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 679 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan003.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 680 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan453.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 681 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan280.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 682 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan582.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 683 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan078.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 684 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan428.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 685 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan097.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 686 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan644.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 687 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan214.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 688 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan701.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 689 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan351.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 690 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan185.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 691 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan490.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 692 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan243.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 693 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan613.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 694 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan306.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 695 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan039.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 696 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan193.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 697 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan469.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 698 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan486.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 699 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan605.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 700 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan255.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 701 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan310.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 702 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan594.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 703 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan081.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 704 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan202.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 705 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan652.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 706 spectra
# Filename: /Users/adrian/Documents/FITS_Library/CaT_library_v9.1_FITS/scan347.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (790, 1)   float32
# Spectra loaded: 707 spectra

# %% [markdown]
# Creating the Dataset

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.1

# %%
label_set = np.asarray(label_set)

# %%
custom_set.shape
# Out:
# (707, 790)

# %%
label_set.shape
# Out:
# (707,)

# %%
augmentation = 50
custom_set = np.repeat(custom_set, augmentation, axis=0)
label_set = np.repeat(label_set, augmentation, axis=0)

# %%
custom_set.shape
# Out:
# (35350, 790)

# %%
label_set.shape
# Out:
# (35350,)

# %%
dataset = tf.data.Dataset.from_tensor_slices((custom_set, label_set))
dataset.element_spec
# Out:
# 2024-01-29 22:10:14.331257: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (TensorSpec(shape=(790,), dtype=tf.float64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %% [markdown]
# Splitting OK

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(custom_set,label_set,test_size=0.2,random_state=123)

# %%
import keras.backend as K

from tensorflow import keras
from tensorflow.keras import layers

from keras.layers import Dense, Input
from keras.models import Model

# %%
input_shape = (dim1,)
input_shape[0]
# Out:
# 790

# %%
latent_dim = 6
intermediate_dim = int(2*dim1/latent_dim)

# %%
dim1
# Out:
# 790

# %%
intermediate_dim
# Out:
# 263

# %%
from tensorflow import keras
from tensorflow.keras import layers

from keras.layers import Dense, Input
from keras.models import Model

from tensorflow.keras import layers, losses


class Autoencoder(tf.keras.Model):
  def __init__(self, latent_dim, intermediate_dim):
    super(Autoencoder, self).__init__()
    self.latent_dim = latent_dim
    self.intermediate_dim = intermediate_dim

    #encoder
    self.encoder = tf.keras.Sequential([
      layers.Flatten(),
      Dense(intermediate_dim, activation='sigmoid', name='intermediate_layer_1'),
      Dense(intermediate_dim/2, activation='sigmoid', name='intermediate_layer_2'),
      Dense(intermediate_dim/4, activation='sigmoid', name='intermediate_layer_3'),
      Dense(intermediate_dim/6, activation='sigmoid', name='intermediate_layer_4'),
      Dense(intermediate_dim/8, activation='sigmoid', name='intermediate_layer_5'),
      Dense(intermediate_dim/16, activation='sigmoid', name='intermediate_layer_6'),



      Dense(latent_dim, activation='sigmoid', name='latent_space') 
    ])
    
    #decoder
    self.decoder = tf.keras.Sequential([
        Dense(intermediate_dim/16, activation='sigmoid', name='intermediate_layer_7'),
        Dense(intermediate_dim/8, activation='sigmoid', name='intermediate_layer_8'),
        Dense(intermediate_dim/6, activation='sigmoid', name='intermediate_layer_9'),
        Dense(intermediate_dim/4, activation='sigmoid', name='intermediate_layer_10'),
        Dense(intermediate_dim/2, activation='sigmoid', name='intermediate_layer_11'),



      Dense(input_shape[0], activation='sigmoid', name='latent_space'),
    #  layers.Reshape((dim1,))
    ])
    
    
  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = Autoencoder(latent_dim, intermediate_dim)

# %%
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

# %%
autoencoder.fit(x_train, x_train,
                epochs=100,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0080 - val_loss: 0.0068
# Epoch 2/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 3/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 4/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 5/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 6/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 7/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 8/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 9/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 10/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 11/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 12/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 13/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 14/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 15/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 16/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 17/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 18/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 19/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 20/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 21/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 22/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 23/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 24/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 25/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 26/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 27/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 28/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 29/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 30/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 31/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 32/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 33/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 34/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 35/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 36/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 37/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 38/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 39/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 40/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 41/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 42/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 43/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 44/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 45/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 46/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 47/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 48/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 49/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 50/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 51/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 52/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 53/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 54/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 55/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 56/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 57/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 58/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 59/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 60/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 61/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 62/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 63/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 64/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 65/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 66/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 67/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 68/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 69/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 70/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 71/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 72/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 73/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 74/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 75/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 76/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 77/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 78/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 79/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 80/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 81/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 82/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 83/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 84/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 85/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 86/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 87/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 88/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 89/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 90/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 91/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 92/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 93/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 94/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 95/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 96/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 97/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 98/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0069
# Epoch 99/100
# 884/884 [==============================] - 2s 3ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 100/100
# 884/884 [==============================] - 3s 3ms/step - loss: 0.0066 - val_loss: 0.0068

# %%
autoencoder.encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 790)               0
#
#  intermediate_layer_1 (Dense  (None, 263)              208033
#  )
#
#  intermediate_layer_2 (Dense  (None, 131)              34584
#  )
#
#  intermediate_layer_3 (Dense  (None, 65)               8580
#  )
#
#  intermediate_layer_4 (Dense  (None, 43)               2838
#  )
#
#  intermediate_layer_5 (Dense  (None, 32)               1408
#  )
#
#  intermediate_layer_6 (Dense  (None, 16)               528
#  )
#
#  latent_space (Dense)        (None, 6)                 102
#
# =================================================================
# Total params: 256,073
# Trainable params: 256,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  intermediate_layer_7 (Dense  (None, 16)               112
#  )
#
#  intermediate_layer_8 (Dense  (None, 32)               544
#  )
#
#  intermediate_layer_9 (Dense  (None, 43)               1419
#  )
#
#  intermediate_layer_10 (Dens  (None, 65)               2860
#  e)
#
#  intermediate_layer_11 (Dens  (None, 131)              8646
#  e)
#
#  latent_space (Dense)        (None, 790)               104280
#
# =================================================================
# Total params: 117,861
# Trainable params: 117,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoded_imgs = autoencoder.encoder(x_test).numpy()
decoded_imgs = autoencoder.decoder(encoded_imgs).numpy()

# %%
encoded_imgs[0]
# Out:
# array([0.45874906, 0.32023224, 0.2537161 , 0.50542986, 0.76031333,
#        0.17399424], dtype=float32)

# %%
figure = 43
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
ax[0].plot(wave2, x_test[figure])
ax[0].set_xlabel('Original Spectra')   
ax[1].plot(wave2, decoded_imgs[figure])
ax[1].set_xlabel('Decoded Spectra')
# Out:
# Text(0.5, 0, 'Decoded Spectra')

# %%
for m in range(20):
    figure = m
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    ax[0].plot(wave2, x_test[figure])
    ax[0].set_xlabel('Original Spectra')   
    ax[1].plot(wave2, decoded_imgs[figure])
    ax[1].set_xlabel('Decoded Spectra')

plt.close(fig)

# %%
for sample in range(20):
    _ = plt.plot(x_test[sample], decoded_imgs[sample], 'o')
    plt.show()
#plt.savefig('train_R2.png')

# %%
encoded_imgs[figure]
# Out:
# array([0.45875186, 0.3202277 , 0.2537174 , 0.5054303 , 0.7603183 ,
#        0.17399503], dtype=float32)

# %%
np.shape(encoded_imgs)
# Out:
# (7070, 6)

# %%
decoded_imgs[figure]
# Out:
# array([0.9100574 , 0.9241014 , 0.947399  , 0.95577145, 0.94682276,
#        0.9331494 , 0.93101025, 0.9349756 , 0.9345989 , 0.9303563 ,
#        0.9238041 , 0.92255193, 0.9338131 , 0.9381511 , 0.933451  ,
#        0.93362015, 0.92999774, 0.9147463 , 0.90821785, 0.9174264 ,
#        0.9294595 , 0.9480897 , 0.961207  , 0.9613523 , 0.9531739 ,
#        0.94727033, 0.94616586, 0.9436907 , 0.93985564, 0.93755406,
#        0.94016856, 0.94347966, 0.93285394, 0.9109991 , 0.9048504 ,
#        0.9309488 , 0.9577147 , 0.963796  , 0.9429737 , 0.8946646 ,
#        0.8753556 , 0.9067495 , 0.9330593 , 0.9323192 , 0.90730584,
#        0.8646014 , 0.85506016, 0.8918041 , 0.9181086 , 0.9278997 ,
#        0.93836516, 0.9477342 , 0.94876546, 0.94199765, 0.93820286,
#        0.9315615 , 0.91578364, 0.9163054 , 0.9344421 , 0.948835  ,
#        0.9518641 , 0.9394378 , 0.92766476, 0.9364885 , 0.9492465 ,
#        0.9466365 , 0.9392977 , 0.94310874, 0.9489659 , 0.9450184 ,
#        0.8931855 , 0.8908895 , 0.88815004, 0.8897598 , 0.8923786 ,
#        0.8896213 , 0.8885067 , 0.892841  , 0.89159757, 0.88937175,
#        0.8904048 , 0.8860107 , 0.8690042 , 0.861877  , 0.8763001 ,
#        0.8900417 , 0.8935714 , 0.8893801 , 0.88634914, 0.88698703,
#        0.8829192 , 0.8714402 , 0.86813426, 0.8806596 , 0.88731575,
#        0.878221  , 0.8701514 , 0.8721424 , 0.8707741 , 0.86332434,
#        0.85167   , 0.8461152 , 0.85028815, 0.8507427 , 0.8543447 ,
#        0.8579329 , 0.8575425 , 0.8596171 , 0.86305493, 0.86997724,
#        0.87878114, 0.884115  , 0.88554907, 0.88606465, 0.88259625,
#        0.87275314, 0.86527884, 0.8632276 , 0.85535157, 0.8464825 ,
#        0.8512161 , 0.84759015, 0.830515  , 0.8215406 , 0.825779  ,
#        0.83622545, 0.844022  , 0.8503395 , 0.8544994 , 0.85102564,
#        0.8442831 , 0.8335139 , 0.81666946, 0.8065772 , 0.8169905 ,
#        0.8402655 , 0.85622925, 0.8610839 , 0.8584187 , 0.8509651 ,
#        0.8367657 , 0.80971557, 0.78281677, 0.7720543 , 0.7752636 ,
#        0.7725892 , 0.7665717 , 0.7805947 , 0.8053552 , 0.8246986 ,
#        0.8278159 , 0.80918866, 0.77978146, 0.76456237, 0.7707811 ,
#        0.78240085, 0.7814629 , 0.7763819 , 0.79439473, 0.8241866 ,
#        0.8386125 , 0.8330343 , 0.8119175 , 0.7918429 , 0.7924375 ,
#        0.8176958 , 0.84470135, 0.8510233 , 0.83532304, 0.8024717 ,
#        0.753476  , 0.70389456, 0.67806387, 0.6782082 , 0.6847928 ,
#        0.6748373 , 0.66410255, 0.68456393, 0.73910797, 0.79516995,
#        0.82817054, 0.8473653 , 0.8531456 , 0.84511894, 0.81788003,
#        0.7567007 , 0.71108574, 0.71810454, 0.7456044 , 0.76746166,
#        0.76171243, 0.7566019 , 0.76861286, 0.78012604, 0.76788306,
#        0.749926  , 0.74376565, 0.7487732 , 0.74820817, 0.7414132 ,
#        0.7316163 , 0.7350114 , 0.7462152 , 0.7469882 , 0.7338334 ,
#        0.70492923, 0.6844984 , 0.7088243 , 0.7627484 , 0.80147314],
#       dtype=float32)

# %%
np.shape(decoded_imgs)
# Out:
# (7070, 790)

# %%
from sklearn.metrics import r2_score
r2_score(x_test, decoded_imgs, multioutput='variance_weighted')
# Out:
# -0.0006185437242121198

# %%
encoded_imgs2 = autoencoder.encoder(x_train).numpy()
decoded_imgs2 = autoencoder.decoder(encoded_imgs2).numpy()

# %%
r2_score(x_train, decoded_imgs2, multioutput='variance_weighted')
# Out:
# -0.0008075375687782876

# %%
r2_score(x_train[43], decoded_imgs2[43], multioutput='variance_weighted')
# Out:
# 0.5143399127087389

# %%
r2_score(x_train[0], decoded_imgs[43], multioutput='variance_weighted')
# Out:
# 0.29263826602689624

# %%
autoencoder.save('6layers_6dim_CaT_autoencoder.tf',save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: 6layers_6dim_CaT_autoencoder.tf/assets
